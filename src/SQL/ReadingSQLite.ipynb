# %%
import pandas as pd
import sqlalchemy as sa


engine = sa.create_engine(f"sqlite:///../../data/311NYC_OpenData.db")

# Do not take limit off it might crash ipykernel by overloading too much data into ram.
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

pd.read_sql(con=engine, sql="Select * From service_requests").head(100)
# Out:
#     request_id         created_date          closed_date agency  \
# 0     63578322  2025-01-01 00:59:59  2025-01-01 12:18:24   NYPD
# 1     63582809  2025-01-01 00:59:56  2025-01-01 01:01:47   NYPD
# 2     63576488  2025-01-01 00:59:55  2025-02-01 17:09:54   NYPD
# 3     63578837  2025-01-01 00:59:54  2025-01-01 01:50:11   NYPD
# 4     63572902  2025-01-01 00:59:22  2025-01-01 02:06:14   NYPD
# 5     63574690  2025-01-01 00:59:17  2025-02-01 17:03:52   NYPD
# 6     63584522  2025-01-01 00:59:15  2025-01-01 01:12:01   NYPD
# 7     63579462  2025-01-01 00:59:13  2025-01-01 01:46:55   NYPD
# 8     63574756  2025-01-01 00:59:04  2025-01-01 02:03:14   NYPD
# 9     63582592  2025-01-01 00:59:01  2025-01-01 01:38:54   NYPD
# 10    63572341  2025-01-01 00:59:00  2025-01-01 01:13:08   NYPD
# 11    63583692  2025-01-01 00:58:58  2025-01-01 01:42:13   NYPD
# 12    63583878  2025-01-01 00:58:44  2025-01-01 01:04:34   NYPD
# 13    63577529  2025-01-01 00:58:43  2025-01-01 01:04:46   NYPD
# ...
