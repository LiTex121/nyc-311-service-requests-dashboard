# %%
import pandas as pd

# %% [markdown]
# Total Rows and Cols

# %%
df = pd.read_csv("../data/Raw/311_Service_Requests_from_2020_to_Present_20260610.csv")
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
A, B = df.shape
print(f"Total Rows: {A} \nTotal Col: {B}")
# Out:
# Total Rows: 650736
# Total Col: 44

# %%
df.shape
# Out:
# (650736, 44)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650736 entries, 0 to 650735
# Data columns (total 44 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Unique Key                            650736 non-null  int64
#  1   Created Date                          650736 non-null  object
#  2   Closed Date                           646349 non-null  object
#  3   Agency                                650736 non-null  object
#  4   Agency Name                           650736 non-null  object
#  5   Problem (formerly Complaint Type)     650736 non-null  object
#  6   Problem Detail (formerly Descriptor)  643835 non-null  object
#  7   Additional Details                    285648 non-null  object
#  8   Location Type                         592049 non-null  object
#  9   Incident Zip                          646700 non-null  float64
# ...
